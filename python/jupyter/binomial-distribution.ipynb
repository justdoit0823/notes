# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binom

# %%
n_tries = 100

# %%
probs = np.linspace(0.1, 0.9, num=9)

# %%
f1, ax = plt.subplots(3, 3, figsize=(30, 20))
f1.subplots_adjust(hspace=0.2, wspace=0.2)
for i, p in enumerate(probs):
    ax[i // 3, i % 3].plot(range(1, n_tries + 1), tuple(binom.pmf(i, 100, p) for i in range(1, n_tries + 1)), 'b+')
    
plt.show()

# %%
f1, ax = plt.subplots(3, 3, figsize=(30, 20))
f1.subplots_adjust(hspace=0.2, wspace=0.2)
for i, p in enumerate(probs):
    ax[i // 3, i % 3].plot(range(1, n_tries + 1), tuple(binom.cdf(i, 100, p) for i in range(1, n_tries + 1)), 'g+')
    
plt.show()
